# %%
import pandas as pd
df=pd.read_csv('Salaries.csv')
df
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_2540\1171937013.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Salaries.csv')
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %% [markdown]
# # Check the first 10 rows

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# # Check last 10 rows

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# # Find the shape of the database

# %%
df.shape
print('Number of rows: ',df.shape[0]) #0 is for rows
print('Number of coloumns: ', df.shape[1])#1 is for columns
# Out:
# Number of rows:  148654
# Number of coloumns:  13

# %% [markdown]
# # Getting information about our dataset like total no. of rows, columns, datatype of each column and memory requirement

# %%
df.info() # memory requirement
df.shape
print('Number of rows: ',df.shape[0]) 
print('Number of coloumns: ', df.shape[1])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB
# Number of rows:  148654
# Number of coloumns:  13

# %% [markdown]
# # Check null values in the dataset

# %%
df.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False    False        False     False
# 148651  False         False     False    False        False     False
# 148652  False         False     False    False        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %% [markdown]
# # Drop ID, notes, agency and status columns

# %%
df.drop(['Id','Notes', 'Agency','Status'],axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# # Find Occurence of the employee Name(top5)

# %%
df['EmployeeName'].value_counts().head(5)
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %% [markdown]
# # Find the number of unique job titles

# %%
df['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %% [markdown]
# # Total number of job titles contains captain

# %%
len(df[df[ 'JobTitle']=='CAPTAIN III (POLICE DEPARTMENT)'])
# Out:
# 37

# %% [markdown]
# # Display all the employee names from fire department

# %%
print(df[df[ 'JobTitle']=='DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)'])
# Out:
#     Id     EmployeeName                                      JobTitle  \
# 4    5  PATRICK GARDNER  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 29  30    MONICA FIELDS  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 42  43  THOMAS SIRAGUSA  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#       BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 4    134401.6      9737.0  182234.59      NaN  326373.19         326373.19
# 29   246225.6         0.0   15140.54      NaN  261366.14         261366.14
# 42  218930.76      4078.0   27330.59      NaN  250339.35         250339.35
#
#     Year  Notes         Agency Status
# 4   2011    NaN  San Francisco    NaN
# 29  2011    NaN  San Francisco    NaN
# 42  2011    NaN  San Francisco    NaN

# %% [markdown]
# # Find min,max and average basepay

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'])   #, errors='coerce' for error somtimes its kernel is sick
maximum=df['BasePay'].max()
minimum=df['BasePay'].min()
Average=df['BasePay'].mean()
print("Maximum number",maximum)
print("Minimum number",minimum)
print("Average number",Average)
# Out:
# Maximum number 319275.01
# Minimum number -166.01
# Average number 66325.4488404877

# %% [markdown]
# # Replace 'Not provided' in emplyeename column to NaN

# %%
import numpy as np
df['EmployeeName']=df['EmployeeName'].replace('Not provided',np.NaN)
df['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %% [markdown]
# # Drop the rows having more than 5 missing values

# %%
df.dropna(thresh=df.shape[1] - 5)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# # Find the job title of Albert Pardini

# %%
data = df[df['EmployeeName'] == 'ALBERT PARDINI']
data['JobTitle'].iloc[0] if not data.empty else 'Employee not found'
# Out:
# 'CAPTAIN III (POLICE DEPARTMENT)'

# %% [markdown]
# # How much Albert Pardini make(include benefits)

# %%
import math
albert_data = df[df['EmployeeName'] == 'ALBERT PARDINI']

if not albert_data.empty:
    base_pay = albert_data['BasePay'].iloc[0]
    overtime_pay = albert_data['OvertimePay'].iloc[0]
    other_pay = albert_data['OtherPay'].iloc[0]
    benefits = albert_data['Benefits'].iloc[0]
    if math.isnan(benefits):
        benefits = 0

    total_compensation = base_pay + overtime_pay + other_pay + benefits

    print(f'Total Compensation ${total_compensation}')
# Out:
# Total Compensation $335279.91

# %% [markdown]
# # Display name of the person having the highest basepay

# %%
df.loc[df['BasePay'].idxmax(),'EmployeeName']
# Out:
# 'Gregory P Suhr'

# %% [markdown]
# # Find average basepay of all employee per year

# %%
df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# # Find avg basepay of employee having job title accountant

# %%
data=df[df['JobTitle'] == 'ACCOUNTANT']
data['BasePay'].mean()
# Out:
# 46643.172

# %% [markdown]
# # Find top 5 most common jobs

# %%
df['JobTitle'].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64
