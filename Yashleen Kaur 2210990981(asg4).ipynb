# %% [markdown]
# # ASSIGNMENT 4

# %%
import mysql.connector as sql
import pandas as pd
db_connection = sql.connect(host='localhost', database='newschema', user='root', password='root')
query="SELECT * FROM train"
df = pd.read_sql(query, con = db_connection)
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11488\2871249402.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, con = db_connection)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # # DISPLAY TOP 5 ROWS OF THE DATASET

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500              S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250              S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500              S

# %% [markdown]
# # CHECK LAST 3 ROWS OF THE DATASET

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  Age  \
# 711          888         1       1  Graham, Miss. Margaret Edith  female   19
# 712          890         1       1         Behr, Mr. Karl Howell    male   26
# 713          891         0       3           Dooley, Mr. Patrick    male   32
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked
# 711      0      0  112053  30.00   B42        S
# 712      0      0  111369  30.00  C148        C
# 713      0      0  370376   7.75              Q

# %% [markdown]
# ## FIND SHAPE OF OUR DATASET(NUMBER OF ROWS & NUMBER OF COLUMNS)

# %%
df.shape
# Out:
# (714, 12)

# %% [markdown]
# # GET INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER ROWS,TOTAL NUMBER OF COLUMNS,DATATYPE OF EACH COLUMN AND MEMORY REQUIREDMENT

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  714 non-null    int64
#  1   Survived     714 non-null    int64
#  2   Pclass       714 non-null    int64
#  3   Name         714 non-null    object
#  4   Sex          714 non-null    object
#  5   Age          714 non-null    int64
#  6   SibSp        714 non-null    int64
#  7   Parch        714 non-null    int64
#  8   Ticket       714 non-null    object
#  9   Fare         714 non-null    float64
#  10  Cabin        714 non-null    object
#  11  Embarked     714 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 67.1+ KB

# %% [markdown]
# # GET OVERALL STATISTICS ABOUT THE DATAFRAME

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   714.000000  714.000000  714.000000  714.000000  714.000000
# mean    448.582633    0.406162    2.236695   29.712885    0.512605
# std     259.119524    0.491460    0.838250   14.529273    0.929783
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     222.250000    0.000000    1.000000   20.250000    0.000000
# 50%     445.000000    0.000000    2.000000   28.000000    0.000000
# 75%     677.750000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  714.000000  714.000000
# mean     0.431373   34.694514
# std      0.853289   52.918930
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.741700
# 75%      1.000000   33.375000
# max      6.000000  512.329200

# %% [markdown]
# # DATA FILTERING

# %%
df

df['Sex'].nunique()
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  Age  \
# 0              1         0       3         Braund, Mr. Owen Harris  male   22
# 4              5         0       3        Allen, Mr. William Henry  male   35
# 5              7         0       1         McCarthy, Mr. Timothy J  male   54
# 6              8         0       3  Palsson, Master. Gosta Leonard  male    2
# 11            13         0       3  Saundercock, Mr. William Henry  male   20
# ..           ...       ...     ...                             ...   ...  ...
# 707          884         0       2   Banfield, Mr. Frederick James  male   28
# 708          885         0       3          Sutehall, Mr. Henry Jr  male   25
# 710          887         0       2           Montvila, Rev. Juozas  male   27
# 712          890         1       1           Behr, Mr. Karl Howell  male   26
# 713          891         0       3             Dooley, Mr. Patrick  male   32
#
# ...

# %%
df['Survived'].nunique()
df[df['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 5              7         0       1               McCarthy, Mr. Timothy J
# 6              8         0       3        Palsson, Master. Gosta Leonard
# 11            13         0       3        Saundercock, Mr. William Henry
# ..           ...       ...     ...                                   ...
# 707          884         0       2         Banfield, Mr. Frederick James
# 708          885         0       3                Sutehall, Mr. Henry Jr
# 709          886         0       3  Rice, Mrs. William (Margaret Norton)
# 710          887         0       2                 Montvila, Rev. Juozas
# 713          891         0       3                   Dooley, Mr. Patrick
#
#         Sex  Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # CHECK NULL VALUES IN THE DATASET

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # DROP THE COLUMN

# %%
df.drop('Cabin',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# # CATEGORICAL DATA ENCODING

# %%
df['Sex'].map({'male': 1, 'female': 0})
pd.get_dummies(df,'Embarked')
# Out:
#      PassengerId  Survived  Pclass  Age  SibSp  Parch     Fare  \
# 0              1         0       3   22      1      0   7.2500
# 1              2         1       1   38      1      0  71.2833
# 2              3         1       3   26      0      0   7.9250
# 3              4         1       1   35      1      0  53.1000
# 4              5         0       3   35      0      0   8.0500
# ..           ...       ...     ...  ...    ...    ...      ...
# 709          886         0       3   39      0      5  29.1250
# 710          887         0       2   27      0      0  13.0000
# 711          888         1       1   19      0      0  30.0000
# 712          890         1       1   26      0      0  30.0000
# 713          891         0       3   32      0      0   7.7500
#
#      Embarked_Abbing, Mr. Anthony  Embarked_Abbott, Mr. Rossmore Edward  \
# 0                           False                                 False
# ...

# %%
pd.get_dummies(df,columns=['Embarked'])
pd.get_dummies(df,columns=['Sex'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name  Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris   22      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   38      1      0
# 2                               Heikkinen, Miss. Laina   26      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   35      1      0
# 4                             Allen, Mr. William Henry   35      0      0
# ..                                                 ...  ...    ...    ...
# ...

# %% [markdown]
# # WHAT IS UNIVARIATE ANALYSIS

# %% [markdown]
# # HOW MANY PEOPLE SURVIVED AND HOW MANY DIED PLOT ON GRAPH

# %%
import matplotlib.pyplot as plt
survival_counts = df['Survived'].value_counts()
plt.figure(figsize=(8, 6))
survival_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Survival Status')
plt.ylabel('Count')
plt.title('Number of Survivors and Non-Survivors')
plt.xticks([0, 1], ['Died', 'Survived'], rotation=0)
plt.show()

# %% [markdown]
# # HOW MANY PASSENGERS WERE IN FIRST CLASS,SECOND CLASS AND THIRD CLASS PLOT THOSE FIGURES ON GRAPH

# %%
# Count the number of passengers in each class
passenger_counts = df['Pclass'].value_counts().sort_index()

# Plotting the counts
plt.figure(figsize=(8, 6))
passenger_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
plt.title('Number of Passengers in Each Passenger Class')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # NUMBER  OF MALE AND FEMALE PASSANGERS

# %%
gender_counts = df['Sex'].value_counts()

print("Number of male passengers:", gender_counts['male'])
print("Number of female passengers:", gender_counts['female'])
# Out:
# Number of male passengers: 453
# Number of female passengers: 261

# %% [markdown]
# # BIVARIANT ANALSIS

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1) 
plt.hist(df['PassengerId'], color='blue', bins=20)
plt.xlabel('PassengerId')
plt.ylabel('Frequency') 
plt.title('Histogram of PassengerId') 
plt.subplot(1, 2, 2) 
plt.hist(df['Age'], color='red', bins=20) 
plt.xlabel('Age')  
plt.ylabel('Frequency') 
plt.title('Histogram of Age')
plt.tight_layout()
plt.show()

# %% [markdown]
# # WHO HAS BETTER CHANCE OF SURVIVAL MALE OR FEMALE

# %%
survival_rates_by_gender = df.groupby('Sex')['Survived'].mean()

plt.figure(figsize=(8, 6))
survival_rates_by_gender.plot(kind='bar', color=['blue', 'pink'])
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Gender')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # WHICH PASSENGER CLASS HAS BETTER CHANCE OF SURVIVAL(FIRST,SECOND,OR THIRD CLASS)?

# %%
survival_rates_by_class = df.groupby('Pclass')['Survived'].mean()
best_class = survival_rates_by_class.idxmax()
plt.figure(figsize=(8, 6))
survival_rates_by_class.plot(kind='bar', color='skyblue')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Passenger Class')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # FEATURE ENGINEERING
